# %% [markdown]
# <a href="https://colab.research.google.com/github/MingmingPeng/DataPreProcessing-/blob/main/tensorflowLearning1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ```
# Tenosrflow exerciese 1:
# Liear Regression Problem
# Predicting Adult Income With Education Level
# ```

# %%
import tensorflow as tf
print('Tensorflow version: {}'.format(tf.__version__))
# Out:
# Tensorflow version: 2.4.1

# %%
import pandas as pd

# %%
data= pd.read_csv('income2.csv')

# %%
data
# Out:
#         Education     Income
# 0    1  10.000000   3.808406
# 1    2  10.401338   3.900919
# 2    3  10.842809   3.161773
# 3    4  11.244147   3.024263
# 4    5  11.645449   2.170376
# 5    6  12.086957   3.771279
# 6    7  12.048829   2.490758
# 7    8  12.889632   3.643984
# 8    9  13.290970   5.269228
# 9   10  13.732441   5.666587
# 10  11  14.133779   4.913754
# 11  12  14.635117   5.928285
# 12  13  14.978589   6.425939
# 13  14  15.377926   6.719942
# 14  15  15.779264   6.893225
# 15  16  16.220736   8.147750
# 16  17  16.622074   7.355846
# 17  18  17.023411   7.333803
# 18  19  17.464883   8.240285
# 19  20  17.866221   9.793388
# 20  21  18.267559   9.187275
# 21  22  18.709030   9.851287
# 22  23  19.110368  10.659234
# 23  24  19.511706  10.266742
# 24  25  19.913043  10.871162
# 25  26  20.354515  10.825031
# 26  27  20.755853  10.355151
# 27  28  21.167191  11.050717
# 28  29  21.598662  10.302684
# 29  30  22.000000  11.465796

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(data.Education, data.Income)

# %%
x=data.Education
y=data.Income

# %%
model = tf.keras.Sequential()

# %%
model.add(tf.keras.layers.Dense(1,input_shape=(1,)))

# %%
model.summary()#ax+b
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 1)                 2
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='mse')

# %%
history=model.fit(x,y, epochs=5000)
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 2501/5000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.4506
# Epoch 2502/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.4505
# Epoch 2503/5000
# 1/1 [==============================] - 0s 27ms/step - loss: 2.4504
# Epoch 2504/5000
# 1/1 [==============================] - 0s 58ms/step - loss: 2.4504
# Epoch 2505/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 2.4503
# Epoch 2506/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.4502
# Epoch 2507/5000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.4501
# Epoch 2508/5000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.4501
# Epoch 2509/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.4500
# Epoch 2510/5000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.4499
# Epoch 2511/5000
# ...

# %%
model.predict(pd.Series([5]))
# Out:
# array([[15.557626]], dtype=float32)
